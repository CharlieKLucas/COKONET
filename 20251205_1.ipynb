# %%
1*3
# Out:
# 3

# %%
# This is a comment with in Code cell

# %%
# to make a mark down cell back to code cell - Click Escape + Y

# %%
# use double click to get back to markdown cell
# Shift + Enter >> To execute

# %%
# Header1

# %%
## Header2

# %% [markdown]
# This ia made comment by choosing markdown

# %% [markdown]
# Short cut to make markdown is Escape + M

# %% [markdown]
# ## Header1

# %% [markdown]
# ## Header2

# %% [markdown]
#  # - Bullets

# %% [markdown]
# - Bullet

# %% [markdown]
# - Bullet
# - 2nd Bullet
